# %%
import solomander as s
import pandas as pd
from solomander.logger import log, stamp, pront
import finplot as fplt

s.test()
df = s.load_data("AAPL", start="2023-01-01", end="2023-12-31")
#print(df.head())

pront.show(df.head())
stamp.critical("Data loaded successfully.")
stamp.info("Data loaded successfully.")

#fplt.plot(df['Close'], title='AAPL Closing Prices')
fplt.candlestick_ochl(df)
fplt.show()
# Out:
# f:\My Documents\Coding\git\Solomander\solomander\data.py:24: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end, interval=interval)
# [*********************100%***********************]  1 of 1 completed
# [22:16:12.457] [DEBUG] data.py|load_data|ln25| Data for AAPL from 2023-01-01 to 2023-12-31 with interval 1d loaded.
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  123.330627  129.079543  122.443142  128.468170  112117500
# 2023-01-04  124.602707  126.870724  123.340509  125.125335   89113600
# 2023-01-05  123.281342  125.993097  123.024963  125.361998   80962700
# 2023-01-06  127.817398  128.478079  123.153181  124.257608   87754700
# 2023-01-09  128.340012  131.554685  128.083633  128.655569   70790800
# [22:16:12.464] Data loaded successfully.
# [22:16:12.464] Data loaded successfully.
# ...
